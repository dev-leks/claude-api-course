# %%
# %run ../setup.py
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
# Implementation of the TextEditorTool
import os
import shutil
from typing import Optional, List


class TextEditorTool:
    def __init__(self, base_dir: str = "", backup_dir: str = ""):
        self.base_dir = base_dir or os.getcwd()
        self.backup_dir = backup_dir or os.path.join(self.base_dir, ".backups")
        os.makedirs(self.backup_dir, exist_ok=True)

    def _validate_path(self, file_path: str) -> str:
        abs_path = os.path.normpath(os.path.join(self.base_dir, file_path))
        if not abs_path.startswith(self.base_dir):
            raise ValueError(
                f"Access denied: Path '{file_path}' is outside the allowed directory"
            )
        return abs_path

    def _backup_file(self, file_path: str) -> str:
        if not os.path.exists(file_path):
            return ""
        file_name = os.path.basename(file_path)
        backup_path = os.path.join(
            self.backup_dir, f"{file_name}.{os.path.getmtime(file_path):.0f}"
        )
        shutil.copy2(file_path, backup_path)
        return backup_path

    def _restore_backup(self, file_path: str) -> str:
        file_name = os.path.basename(file_path)
        backups = [
            f for f in os.listdir(self.backup_dir) if f.startswith(file_name + ".")
        ]
        if not backups:
            raise FileNotFoundError(f"No backups found for {file_path}")

        latest_backup = sorted(backups, reverse=True)[0]
        backup_path = os.path.join(self.backup_dir, latest_backup)

        shutil.copy2(backup_path, file_path)
        return f"Successfully restored {file_path} from backup"

    def _count_matches(self, content: str, old_str: str) -> int:
        return content.count(old_str)

    def view(self, file_path: str, view_range: Optional[List[int]] = None) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if os.path.isdir(abs_path):
                try:
                    return "\n".join(os.listdir(abs_path))
                except PermissionError:
                    raise PermissionError(
                        "Permission denied. Cannot list directory contents."
                    )

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            if view_range:
                start, end = view_range
                lines = content.split("\n")

                if end == -1:
                    end = len(lines)

                selected_lines = lines[start - 1 : end]

                result = []
                for i, line in enumerate(selected_lines, start):
                    result.append(f"{i}: {line}")

                return "\n".join(result)
            else:
                lines = content.split("\n")
                result = []
                for i, line in enumerate(lines, 1):
                    result.append(f"{i}: {line}")

                return "\n".join(result)

        except UnicodeDecodeError:
            raise UnicodeDecodeError(
                "utf-8",
                b"",
                0,
                1,
                "File contains non-text content and cannot be displayed.",
            )
        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot access file.")
        except Exception as e:
            raise type(e)(str(e))

    def str_replace(self, file_path: str, old_str: str, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            match_count = self._count_matches(content, old_str)

            if match_count == 0:
                raise ValueError(
                    "No match found for replacement. Please check your text and try again."
                )
            elif match_count > 1:
                raise ValueError(
                    f"Found {match_count} matches for replacement text. Please provide more context to make a unique match."
                )

            # Create backup before modifying
            self._backup_file(abs_path)

            # Perform the replacement
            new_content = content.replace(old_str, new_str)

            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(new_content)

            return "Successfully replaced text at exactly one location."

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def create(self, file_path: str, file_text: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            # Check if file already exists
            if os.path.exists(abs_path):
                raise FileExistsError(
                    "File already exists. Use str_replace to modify it."
                )

            # Create parent directories if they don't exist
            os.makedirs(os.path.dirname(abs_path), exist_ok=True)

            # Create the file
            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(file_text)

            return f"Successfully created {file_path}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot create file.")
        except Exception as e:
            raise type(e)(str(e))

    def insert(self, file_path: str, insert_line: int, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            # Create backup before modifying
            self._backup_file(abs_path)

            with open(abs_path, "r", encoding="utf-8") as f:
                lines = f.readlines()

            # Handle line endings
            if lines and not lines[-1].endswith("\n"):
                new_str = "\n" + new_str

            # Insert at the beginning if insert_line is 0
            if insert_line == 0:
                lines.insert(0, new_str + "\n")
            # Insert after the specified line
            elif insert_line > 0 and insert_line <= len(lines):
                lines.insert(insert_line, new_str + "\n")
            else:
                raise IndexError(
                    f"Line number {insert_line} is out of range. File has {len(lines)} lines."
                )

            with open(abs_path, "w", encoding="utf-8") as f:
                f.writelines(lines)

            return f"Successfully inserted text after line {insert_line}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def undo_edit(self, file_path: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            return self._restore_backup(abs_path)

        except ValueError as e:
            raise ValueError(str(e))
        except FileNotFoundError:
            raise FileNotFoundError("No previous edits to undo")
        except PermissionError:
            raise PermissionError("Permission denied. Cannot restore file.")
        except Exception as e:
            raise type(e)(str(e))

# %%
# Process Tool Call Requests
import json

text_editor_tool = TextEditorTool()


def run_tool(tool_name, tool_input):
    if tool_name in ("str_replace_editor", "str_replace_based_edit_tool"):
        command = tool_input["command"]
        if command == "view":
            return text_editor_tool.view(
                tool_input["path"], tool_input.get("view_range")
            )
        elif command == "str_replace":
            return text_editor_tool.str_replace(
                tool_input["path"], tool_input["old_str"], tool_input["new_str"]
            )
        elif command == "create":
            return text_editor_tool.create(tool_input["path"], tool_input["file_text"])
        elif command == "insert":
            return text_editor_tool.insert(
                tool_input["path"],
                tool_input["insert_line"],
                tool_input["new_str"],
            )
        elif command == "undo_edit":
            return text_editor_tool.undo_edit(tool_input["path"])
        else:
            raise Exception(f"Unknown text editor command: {command}")
    else:
        raise Exception(f"Unknown tool name: {tool_name}")


def run_tools(message):
    tool_requests = [block for block in message.content if block.type == "tool_use"]
    tool_result_blocks = []

    for tool_request in tool_requests:
        try:
            tool_output = run_tool(tool_request.name, tool_request.input)
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": json.dumps(tool_output),
                "is_error": False,
            }
        except Exception as e:
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": f"Error: {e}",
                "is_error": True,
            }

        tool_result_blocks.append(tool_result_block)

    return tool_result_blocks

# %%
# Make the text edit schema based on the model version being used
def get_text_edit_schema(model):
    return {
        "type": "text_editor_20250728",
        "name": "str_replace_based_edit_tool",
    }

# %%
# Run the conversation in a loop until the model doesn't ask for a tool use
def run_conversation(messages):
    while True:
        response = chat(
            messages,
            tools=[get_text_edit_schema(model)],
        )

        add_assistant_message(messages, response)
        print(text_from_message(response))

        if response.stop_reason != "tool_use":
            break

        tool_results = run_tools(response)
        add_user_message(messages, tool_results)

    return messages

# %%
messages = []

add_user_message(
    messages,
    """
    Open the ./main.py file and write out a function to calculate pi to the 5th digit.

    Then create a ./test.py file with tests to verify your implementation.
    """,
)

run_conversation(messages)
# Out:
# I'll help you create a function to calculate pi to the 5th digit and write tests for it. Let me start by viewing the current main.py file and then implementing the solution.
# Good! The main.py file already has a `calculate_pi` function. Now let me create a comprehensive test file to verify the implementation:
# Perfect! I've created a comprehensive test suite. Let me verify both files are correctly set up:
# Perfect! I've successfully completed both tasks:
#
# ## Summary
#
# ### **main.py** - Already contains the `calculate_pi()` function
# The function:
# - Calculates π to the 5th decimal digit by default (3.14159)
# - Uses **Machin's formula**: π/4 = 4×arctan(1/5) - arctan(1/239)
# - Implements arctan using Taylor series expansion for accuracy
# - Uses Python's `Decimal` module for high precision arithmetic
# - Returns a float rounded to the specified number of digits
#
# ### **test.py** - Comprehensive test suite created
# The test file includes 10 tests that verify:
# 1. ✅ **Pi to 5 decimal places** (3.14159) - the main requirement
# 2. ✅ **Pi to 1 decimal place** (3.1)
# 3. ✅ **Pi to 2 decimal places** (3.14)
# 4. ✅ **Pi to 3 decimal places** (3.142)
# 5. ✅ **Pi to 4 decimal places** (3.1416)
# 6. ✅ **Default parameter** uses 5 digits
# 7. ✅ **Higher precision** (10 digits: 3.1415926536)
# 8. ✅ **Return type** is float
# 9. ✅ **Value is greater than 3**
# 10. ✅ **Value is less than 4**
#
# You can run the tests by executing:
# ```bash
# python test.py
# ```
#
# The implementation uses a mathematically sound approach (Machin's formula) which is efficient and accurate for calculating π to moderate precision.
# [{'role': 'user',
#   'content': '\n    Open the ./main.py file and write out a function to calculate pi to the 5th digit.\n\n    Then create a ./test.py file with tests to verify your implementation.\n    '},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="I'll help you create a function to calculate pi to the 5th digit and write tests for it. Let me start by viewing the current main.py file and then implementing the solution.", type='text'),
#    ToolUseBlock(id='toolu_01MxfY4s4ysx3UV7wTCPZ45m', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01MxfY4s4ysx3UV7wTCPZ45m',
#     'content': '"1: def greeting():\\n2:     print(\\"Hi there!\\")\\n3: \\n4: \\n5: def calculate_pi(digits=5):\\n6:     \\"\\"\\"\\n7:     Calculate pi to the specified number of decimal digits using the Machin formula.\\n8:     \\n9:     Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\\n10:     \\n11:     Args:\\n12:         digits: Number of decimal digits to calculate (default: 5)\\n13:     \\n14:     Returns:\\n15:         float: Approximation of pi to the specified number of digits\\n16:     \\"\\"\\"\\n17:     from decimal import Decimal, getcontext\\n18:     \\n19:     # Set precision high enough to get accurate result\\n20:     # We need extra precision for intermediate calculations\\n21:     getcontext().prec = digits + 10\\n22:     \\n23:     def arctan(x, num_terms=100):\\n24:         \\"\\"\\"Calculate arctan using Taylor series expansion.\\"\\"\\"\\n25:         x = Decimal(x)\\n26:         power = x\\n27:         result = power\\n28:         for n in range(1, num_terms):\\n29:             power *= -x * x\\n30:             result += power / (2 * n + 1)\\n31:         return result\\n32:     \\n33:     # Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\\n34:     pi_over_4 = 4 * arctan(Decimal(1) / Decimal(5), 500) - arctan(Decimal(1) / Decimal(239), 500)\\n35:     pi_value = 4 * pi_over_4\\n36:     \\n37:     # Round to the specified number of digits\\n38:     return round(float(pi_value), digits)"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Good! The main.py file already has a `calculate_pi` function. Now let me create a comprehensive test file to verify the implementation:', type='text'),
#    ToolUseBlock(id='toolu_01FreS9p7r14Qm5ouAhxvvtW', caller=DirectCaller(type='direct'), input={'command': 'create', 'path': './test.py', 'file_text': 'import unittest\nfrom main import calculate_pi\n\n\nclass TestCalculatePi(unittest.TestCase):\n    """Test suite for the calculate_pi function."""\n    \n    def test_pi_to_5_digits(self):\n        """Test that pi is calculated correctly to 5 decimal places."""\n        result = calculate_pi(5)\n        expected = 3.14159  # pi to 5 decimal places\n        self.assertEqual(result, expected, \n                        f"Expected {expected}, but got {result}")\n    \n    def test_pi_to_1_digit(self):\n        """Test that pi is calculated correctly to 1 decimal place."""\n        result = calculate_pi(1)\n        expected = 3.1\n        self.assertEqual(result, expected,\n                        f"Expected {expected}, but got {result}")\n    \n    def test_pi_to_2_digits(self):\n        """Test that pi is calculated correctly to 2 decimal places."""\n        result = calculate_pi(2)\n        expected = 3.14\n        self.assertEqual(result, expected,\n                        f"Expected {expected}, but got {result}")\n    \n    def test_pi_to_3_digits(self):\n        """Test that pi is calculated correctly to 3 decimal places."""\n        result = calculate_pi(3)\n        expected = 3.142\n        self.assertEqual(result, expected,\n                        f"Expected {expected}, but got {result}")\n    \n    def test_pi_to_4_digits(self):\n        """Test that pi is calculated correctly to 4 decimal places."""\n        result = calculate_pi(4)\n        expected = 3.1416\n        self.assertEqual(result, expected,\n                        f"Expected {expected}, but got {result}")\n    \n    def test_pi_default_parameter(self):\n        """Test that the default parameter calculates to 5 digits."""\n        result = calculate_pi()\n        expected = 3.14159\n        self.assertEqual(result, expected,\n                        f"Expected {expected}, but got {result}")\n    \n    def test_pi_to_higher_precision(self):\n        """Test that pi can be calculated to higher precision (10 digits)."""\n        result = calculate_pi(10)\n        expected = 3.1415926536\n        self.assertEqual(result, expected,\n                        f"Expected {expected}, but got {result}")\n    \n    def test_return_type(self):\n        """Test that the function returns a float."""\n        result = calculate_pi(5)\n        self.assertIsInstance(result, float,\n                            f"Expected float type, but got {type(result)}")\n    \n    def test_pi_greater_than_3(self):\n        """Test that pi is greater than 3."""\n        result = calculate_pi(5)\n        self.assertGreater(result, 3,\n                          f"Pi should be greater than 3, but got {result}")\n    \n    def test_pi_less_than_4(self):\n        """Test that pi is less than 4."""\n        result = calculate_pi(5)\n        self.assertLess(result, 4,\n                       f"Pi should be less than 4, but got {result}")\n\n\nif __name__ == \'__main__\':\n    # Run the tests with verbose output\n    unittest.main(verbosity=2)\n'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01FreS9p7r14Qm5ouAhxvvtW',
#     'content': '"Successfully created ./test.py"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Perfect! I've created a comprehensive test suite. Let me verify both files are correctly set up:", type='text'),
#    ToolUseBlock(id='toolu_01WxHZT6f2iGwtpbPpwzQFFf', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use'),
#    ToolUseBlock(id='toolu_01T64QdMxjME25ZisQ3DwH2S', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './test.py'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01WxHZT6f2iGwtpbPpwzQFFf',
#     'content': '"1: def greeting():\\n2:     print(\\"Hi there!\\")\\n3: \\n4: \\n5: def calculate_pi(digits=5):\\n6:     \\"\\"\\"\\n7:     Calculate pi to the specified number of decimal digits using the Machin formula.\\n8:     \\n9:     Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\\n10:     \\n11:     Args:\\n12:         digits: Number of decimal digits to calculate (default: 5)\\n13:     \\n14:     Returns:\\n15:         float: Approximation of pi to the specified number of digits\\n16:     \\"\\"\\"\\n17:     from decimal import Decimal, getcontext\\n18:     \\n19:     # Set precision high enough to get accurate result\\n20:     # We need extra precision for intermediate calculations\\n21:     getcontext().prec = digits + 10\\n22:     \\n23:     def arctan(x, num_terms=100):\\n24:         \\"\\"\\"Calculate arctan using Taylor series expansion.\\"\\"\\"\\n25:         x = Decimal(x)\\n26:         power = x\\n27:         result = power\\n28:         for n in range(1, num_terms):\\n29:             power *= -x * x\\n30:             result += power / (2 * n + 1)\\n31:         return result\\n32:     \\n33:     # Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\\n34:     pi_over_4 = 4 * arctan(Decimal(1) / Decimal(5), 500) - arctan(Decimal(1) / Decimal(239), 500)\\n35:     pi_value = 4 * pi_over_4\\n36:     \\n37:     # Round to the specified number of digits\\n38:     return round(float(pi_value), digits)"',
#     'is_error': False},
#    {'type': 'tool_result',
#     'tool_use_id': 'toolu_01T64QdMxjME25ZisQ3DwH2S',
#     'content': '"1: import unittest\\n2: from main import calculate_pi\\n3: \\n4: \\n5: class TestCalculatePi(unittest.TestCase):\\n6:     \\"\\"\\"Test suite for the calculate_pi function.\\"\\"\\"\\n7:     \\n8:     def test_pi_to_5_digits(self):\\n9:         \\"\\"\\"Test that pi is calculated correctly to 5 decimal places.\\"\\"\\"\\n10:         result = calculate_pi(5)\\n11:         expected = 3.14159  # pi to 5 decimal places\\n12:         self.assertEqual(result, expected, \\n13:                         f\\"Expected {expected}, but got {result}\\")\\n14:     \\n15:     def test_pi_to_1_digit(self):\\n16:         \\"\\"\\"Test that pi is calculated correctly to 1 decimal place.\\"\\"\\"\\n17:         result = calculate_pi(1)\\n18:         expected = 3.1\\n19:         self.assertEqual(result, expected,\\n20:                         f\\"Expected {expected}, but got {result}\\")\\n21:     \\n22:     def test_pi_to_2_digits(self):\\n23:         \\"\\"\\"Test that pi is calculated correctly to 2 decimal places.\\"\\"\\"\\n24:         result = calculate_pi(2)\\n25:         expected = 3.14\\n26:         self.assertEqual(result, expected,\\n27:                         f\\"Expected {expected}, but got {result}\\")\\n28:     \\n29:     def test_pi_to_3_digits(self):\\n30:         \\"\\"\\"Test that pi is calculated correctly to 3 decimal places.\\"\\"\\"\\n31:         result = calculate_pi(3)\\n32:         expected = 3.142\\n33:         self.assertEqual(result, expected,\\n34:                         f\\"Expected {expected}, but got {result}\\")\\n35:     \\n36:     def test_pi_to_4_digits(self):\\n37:         \\"\\"\\"Test that pi is calculated correctly to 4 decimal places.\\"\\"\\"\\n38:         result = calculate_pi(4)\\n39:         expected = 3.1416\\n40:         self.assertEqual(result, expected,\\n41:                         f\\"Expected {expected}, but got {result}\\")\\n42:     \\n43:     def test_pi_default_parameter(self):\\n44:         \\"\\"\\"Test that the default parameter calculates to 5 digits.\\"\\"\\"\\n45:         result = calculate_pi()\\n46:         expected = 3.14159\\n47:         self.assertEqual(result, expected,\\n48:                         f\\"Expected {expected}, but got {result}\\")\\n49:     \\n50:     def test_pi_to_higher_precision(self):\\n51:         \\"\\"\\"Test that pi can be calculated to higher precision (10 digits).\\"\\"\\"\\n52:         result = calculate_pi(10)\\n53:         expected = 3.1415926536\\n54:         self.assertEqual(result, expected,\\n55:                         f\\"Expected {expected}, but got {result}\\")\\n56:     \\n57:     def test_return_type(self):\\n58:         \\"\\"\\"Test that the function returns a float.\\"\\"\\"\\n59:         result = calculate_pi(5)\\n60:         self.assertIsInstance(result, float,\\n61:                             f\\"Expected float type, but got {type(result)}\\")\\n62:     \\n63:     def test_pi_greater_than_3(self):\\n64:         \\"\\"\\"Test that pi is greater than 3.\\"\\"\\"\\n65:         result = calculate_pi(5)\\n66:         self.assertGreater(result, 3,\\n67:                           f\\"Pi should be greater than 3, but got {result}\\")\\n68:     \\n69:     def test_pi_less_than_4(self):\\n70:         \\"\\"\\"Test that pi is less than 4.\\"\\"\\"\\n71:         result = calculate_pi(5)\\n72:         self.assertLess(result, 4,\\n73:                        f\\"Pi should be less than 4, but got {result}\\")\\n74: \\n75: \\n76: if __name__ == \'__main__\':\\n77:     # Run the tests with verbose output\\n78:     unittest.main(verbosity=2)\\n79: "',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Perfect! I've successfully completed both tasks:\n\n## Summary\n\n### **main.py** - Already contains the `calculate_pi()` function\nThe function:\n- Calculates π to the 5th decimal digit by default (3.14159)\n- Uses **Machin's formula**: π/4 = 4×arctan(1/5) - arctan(1/239)\n- Implements arctan using Taylor series expansion for accuracy\n- Uses Python's `Decimal` module for high precision arithmetic\n- Returns a float rounded to the specified number of digits\n\n### **test.py** - Comprehensive test suite created\nThe test file includes 10 tests that verify:\n1. ✅ **Pi to 5 decimal places** (3.14159) - the main requirement\n2. ✅ **Pi to 1 decimal place** (3.1)\n3. ✅ **Pi to 2 decimal places** (3.14)\n4. ✅ **Pi to 3 decimal places** (3.142)\n5. ✅ **Pi to 4 decimal places** (3.1416)\n6. ✅ **Default parameter** uses 5 digits\n7. ✅ **Higher precision** (10 digits: 3.1415926536)\n8. ✅ **Return type** is float\n9. ✅ **Value is greater than 3**\n10. ✅ **Value is less than 4**\n\nYou can run the tests by executing:\n```bash\npython test.py\n```\n\nThe implementation uses a mathematically sound approach (Machin's formula) which is efficient and accurate for calculating π to moderate precision.", type='text')]}]
